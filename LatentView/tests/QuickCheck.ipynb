# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname("__file__"), '../src')))

# %%
from utilities import fetch_dictionary_information, fetch_dictionary_file
from character_tree import CharacterMap

# %%
dict_file_path = fetch_dictionary_information()
k1 = fetch_dictionary_file(dict_file_path)

# %%
fetch_dictionary_information()
# Out:
# '../working\\shelve_dict.pickle'

# %%
k1
# Out:
# {'tootsy': <character_tree.CharacterMap at 0x17ac1af42c8>,
#  'autodidactic': <character_tree.CharacterMap at 0x17ac1af4448>,
#  'clavelize': <character_tree.CharacterMap at 0x17ac1af44c8>,
#  'enodal': <character_tree.CharacterMap at 0x17ac1af4548>,
#  'recurtain': <character_tree.CharacterMap at 0x17ac1af45c8>,
#  'tolylene': <character_tree.CharacterMap at 0x17ac1af4648>,
#  'revealment': <character_tree.CharacterMap at 0x17ac1af46c8>,
#  'slummage': <character_tree.CharacterMap at 0x17ac1af4748>,
#  'oppositipinnate': <character_tree.CharacterMap at 0x17ac1af4808>,
#  'necessist': <character_tree.CharacterMap at 0x17ac1af48c8>,
#  'chondrostei': <character_tree.CharacterMap at 0x17ac1af4988>,
#  'hemosiderin': <character_tree.CharacterMap at 0x17ac1af4a48>,
#  'beallach': <character_tree.CharacterMap at 0x17ac1af4b08>,
#  'satirize': <character_tree.CharacterMap at 0x17ac1af4bc8>,
#  'scorchingness': <character_tree.CharacterMap at 0x17ac1af4c88>,
# ...
